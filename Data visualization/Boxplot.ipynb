# %% [markdown]
# # Boxplot
#
# - A boxplot is a standardized way of displaying the distribution of data based on five number summary
#   ("minimum", first quartile(Q1), median, thirdquartile(Q3) and "maximum". It can tell us about the o   outliers and what are their values. It can also tell us if the data is symmetrical, how tightly the
#   data is grouped, and how the data is skewed.

# %%
#Import necessary library
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('cars.csv')
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df.describe()
# Out:
#         symboling       width      height  engine-size    city-mpg  \
# count  205.000000  205.000000  205.000000   205.000000  205.000000
# mean     0.834146   65.907805   53.724878   126.907317   25.219512
# std      1.245307    2.145204    2.443522    41.642693    6.542142
# min     -2.000000   60.300000   47.800000    61.000000   13.000000
# 25%      0.000000   64.100000   52.000000    97.000000   19.000000
# 50%      1.000000   65.500000   54.100000   120.000000   24.000000
# 75%      2.000000   66.900000   55.500000   141.000000   30.000000
# max      3.000000   72.300000   59.800000   326.000000   49.000000
#
#        highway-mpg         price
# count   205.000000    205.000000
# mean     30.751220  13227.478049
# std       6.886443   7902.651615
# min      16.000000   5118.000000
# 25%      25.000000   7788.000000
# 50%      30.000000  10345.000000
# 75%      34.000000  16500.000000
# max      54.000000  45400.000000

# %%
df.describe(include = 'all')
# Out:
#          symboling normalized-losses    make fuel-type body-style  \
# count   205.000000               205     205       205        205
# unique         NaN                52      22         2          5
# top            NaN                 ?  toyota       gas      sedan
# freq           NaN                41      32       185         96
# mean      0.834146               NaN     NaN       NaN        NaN
# std       1.245307               NaN     NaN       NaN        NaN
# min      -2.000000               NaN     NaN       NaN        NaN
# 25%       0.000000               NaN     NaN       NaN        NaN
# 50%       1.000000               NaN     NaN       NaN        NaN
# 75%       2.000000               NaN     NaN       NaN        NaN
# max       3.000000               NaN     NaN       NaN        NaN
#
#        drive-wheels engine-location       width      height engine-type  \
# count           205             205  205.000000  205.000000         205
# ...

# %%
#Set the figure size of the graph

# %%
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 300

# %%
#Selecting numerical columns

# %%
num_col = df.select_dtypes([int,float])
num_col
# Out:
#      symboling  width  height  engine-size  city-mpg  highway-mpg  price
# 0            3   64.1    48.8          130        21           27  13495
# 1            3   64.1    48.8          130        21           27  16500
# 2            1   65.5    52.4          152        19           26  16500
# 3            2   66.2    54.3          109        24           30  13950
# 4            2   66.4    54.3          136        18           22  17450
# ..         ...    ...     ...          ...       ...          ...    ...
# 200         -1   68.9    55.5          141        23           28  16845
# 201         -1   68.8    55.5          141        19           25  19045
# 202         -1   68.9    55.5          173        18           23  21485
# 203         -1   68.9    55.5          145        26           27  22470
# 204         -1   68.9    55.5          141        19           25  22625
#
# [205 rows x 7 columns]

# %%
#Matplotlib boxplot

# %%
plt.boxplot(df['symboling'], notch=True, patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29b18ebd850>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x29b18ed2b80>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x29b18ebd640>],
#  'medians': [<matplotlib.lines.Line2D at 0x29b18eb43d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29b18eb4bb0>],
#  'means': []}

# %%
plt.boxplot(num_col)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29b18e062e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x29b18e06880>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29b18176fa0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x29b18e06e20>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x29b18e14130>,
# ...
#  'means': []}

# %%
num_col.drop(columns=['price', 'engine-size']).boxplot()
# Out:
# <AxesSubplot:>

# %%
plt.boxplot(num_col['highway-mpg'])
plt.grid()

# %% [markdown]
# # Seaborn boxplot

# %%
#Set theme and style

# %%
sns.set_theme(style ='darkgrid', palette ='deep')
df.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
sns.boxplot(df['price'])
# Out:
# <AxesSubplot:xlabel='price'>

# %%
sns.boxplot(df['price'], df['make'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='make'>
